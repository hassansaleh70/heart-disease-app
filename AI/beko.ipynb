# %%
a = float(input('pleas enter the first number = '))
b = float(input('please enter the second number = '))

# %%
print(f'the result of Addition = {a+b}')
print(f'the result of Subtraction = {a-b}')
print(f'the result of Multiplication = {a*b}')
print(f'the result of Division = {a/b}')
# Out:
# the result of Addition = 7.0
# the result of Subtraction = -3.0
# the result of Multiplication = 10.0
# the result of Division = 0.4
